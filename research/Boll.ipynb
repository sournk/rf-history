# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.4 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.74

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = yf.download('MSFT', start='2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  214.479111
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  214.686005
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  209.119324
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  215.070251
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  216.380630
# ...                ...         ...         ...         ...         ...
# 2022-08-15  291.000000  294.179993  290.109985  293.470001  292.848389
# 2022-08-16  291.989990  294.040009  290.420013  292.709991  292.089996
# 2022-08-17  289.739990  293.350006  289.470001  291.320007  291.320007
# 2022-08-18  290.190002  291.910004  289.079987  290.170013  290.170013
# 2022-08-19  288.899994  289.250000  285.637085  286.320007  286.320007
#
#               Volume
# Date
# 2021-01-04  37130100
# 2021-01-05  23823000
# 2021-01-06  35930700
# 2021-01-07  27694500
# 2021-01-08  22956200
# ...              ...
# 2022-08-15  18085700
# 2022-08-16  18102900
# 2022-08-17  18253400
# 2022-08-18  17173400
# 2022-08-19  12230735
#
# [411 rows x 6 columns]

# %%
df['SMA'] = df.Close.rolling(window=20).mean()

# %%
df['stddev'] = df.Close.rolling(window=20).std()

# %%
df['Upper'] = df.SMA + 2* df.stddev
df['Lower'] = df.SMA - 2* df.stddev

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  214.479111
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  214.686005
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  209.119324
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  215.070251
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  216.380630
# ...                ...         ...         ...         ...         ...
# 2022-08-15  291.000000  294.179993  290.109985  293.470001  292.848389
# 2022-08-16  291.989990  294.040009  290.420013  292.709991  292.089996
# 2022-08-17  289.739990  293.350006  289.470001  291.320007  291.320007
# 2022-08-18  290.190002  291.910004  289.079987  290.170013  290.170013
# 2022-08-19  288.899994  289.250000  285.637085  286.320007  286.320007
#
#               Volume         SMA     stddev       Upper       Lower
# Date
# 2021-01-04  37130100         NaN        NaN         NaN         NaN
# 2021-01-05  23823000         NaN        NaN         NaN         NaN
# 2021-01-06  35930700         NaN        NaN         NaN         NaN
# 2021-01-07  27694500         NaN        NaN         NaN         NaN
# 2021-01-08  22956200         NaN        NaN         NaN         NaN
# ...              ...         ...        ...         ...         ...
# 2022-08-15  18085700  275.482997  12.224691  299.932379  251.033615
# 2022-08-16  18102900  277.141997  12.197161  301.536319  252.747675
# 2022-08-17  18253400  278.594498  12.061876  302.718249  254.470746
# 2022-08-18  17173400  279.860999  11.869940  303.600878  256.121119
# 2022-08-19  12230735  281.159000  11.013740  303.186480  259.131519
#
# [411 rows x 10 columns]

# %%
df['Buy_Signal'] = np.where(df.Lower > df.Close, True, False)
df['Sell_Signal'] = np.where(df.Upper < df.Close, True, False)

# %%
df = df.dropna()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-01  235.059998  242.500000  232.429993  239.649994  236.115219
# 2021-02-02  241.300003  242.309998  238.690002  239.509995  235.977264
# 2021-02-03  239.570007  245.089996  239.259995  243.000000  239.415802
# 2021-02-04  242.660004  243.240005  240.369995  242.009995  238.440399
# 2021-02-05  242.229996  243.279999  240.419998  242.199997  238.627579
# ...                ...         ...         ...         ...         ...
# 2022-08-15  291.000000  294.179993  290.109985  293.470001  292.848389
# 2022-08-16  291.989990  294.040009  290.420013  292.709991  292.089996
# 2022-08-17  289.739990  293.350006  289.470001  291.320007  291.320007
# 2022-08-18  290.190002  291.910004  289.079987  290.170013  290.170013
# 2022-08-19  288.899994  289.250000  285.637085  286.320007  286.320007
#
#               Volume         SMA     stddev       Upper       Lower  \
# Date
# 2021-02-01  33314200  222.858998   8.723604  240.306207  205.411789
# 2021-02-02  25916300  223.949998   9.382671  242.715339  205.184656
# 2021-02-03  27158100  225.204998  10.175966  245.556929  204.853067
# 2021-02-04  25296100  226.692998  10.356153  247.405304  205.980691
# 2021-02-05  18054800  227.888498  10.709122  249.306741  206.470255
# ...              ...         ...        ...         ...         ...
# 2022-08-15  18085700  275.482997  12.224691  299.932379  251.033615
# 2022-08-16  18102900  277.141997  12.197161  301.536319  252.747675
# 2022-08-17  18253400  278.594498  12.061876  302.718249  254.470746
# 2022-08-18  17173400  279.860999  11.869940  303.600878  256.121119
# 2022-08-19  12230735  281.159000  11.013740  303.186480  259.131519
#
#             Buy_Signal  Sell_Signal
# Date
# 2021-02-01       False        False
# 2021-02-02       False        False
# 2021-02-03       False        False
# 2021-02-04       False        False
# 2021-02-05       False        False
# ...                ...          ...
# 2022-08-15       False        False
# 2022-08-16       False        False
# 2022-08-17       False        False
# 2022-08-18       False        False
# 2022-08-19       False        False
#
# [392 rows x 12 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(df[['Close', 'SMA', 'Upper', 'Lower']])
plt.scatter(df.index[df.Buy_Signal], df[df.Buy_Signal].Close, marker = '^', color='g')
plt.scatter(df.index[df.Sell_Signal], df[df.Sell_Signal].Close, marker = 'v', color='r')
plt.fill_between(df.index, df.Upper, df.Lower, color='grey', alpha=0.3)
plt.legend(['Close', 'SMA', 'Upper', 'Lower'])
plt.show()

# %%
buys = []
sells = []
open_pos = False

for i in range(len(df)):
  if df.Lower[i] > df.Close[i]:
    if open_pos == False:
      buys.append(i)
      open_pos = True
  elif df.Upper[i] < df.Close[i]:
    if open_pos:
      sells.append(i)
      open_pos = False

# %%
buys
# Out:
# [17, 64, 160, 213]

# %%
sells
# Out:
# [42, 90, 187, 375]

# %%
plt.figure(figsize=(20, 10))
plt.plot(df[['Close', 'SMA', 'Upper', 'Lower']])
plt.scatter(df.iloc[buys].index, df.iloc[buys].Close, marker = '^', color='g')
plt.scatter(df.iloc[sells].index, df.iloc[sells].Close, marker = 'v', color='r')
plt.fill_between(df.index, df.Upper, df.Lower, color='grey', alpha=0.3)
plt.legend(['Close', 'SMA', 'Upper', 'Lower'])
plt.show()

# %%
merged = pd.concat([df.iloc[buys].Close, df.iloc[sells].Close], axis=1)

# %%
merged
# Out:
#                  Close       Close
# Date
# 2021-02-25  228.990005         NaN
# 2021-04-01         NaN  242.350006
# 2021-05-04  247.789993         NaN
# 2021-06-10         NaN  257.239990
# 2021-09-20  294.299988         NaN
# 2021-10-27         NaN  323.170013
# 2021-12-03  323.010010         NaN
# 2022-07-28         NaN  276.410004

# %%
merged.columns = ['Buys', 'Sells']

# %%
merged
# Out:
#                   Buys       Sells
# Date
# 2021-02-25  228.990005         NaN
# 2021-04-01         NaN  242.350006
# 2021-05-04  247.789993         NaN
# 2021-06-10         NaN  257.239990
# 2021-09-20  294.299988         NaN
# 2021-10-27         NaN  323.170013
# 2021-12-03  323.010010         NaN
# 2022-07-28         NaN  276.410004

# %%
totalprofit = merged.shift(-1).Sells - merged.Buys

# %%
totalprofit
# Out:
# Date
# 2021-02-25    13.360001
# 2021-04-01          NaN
# 2021-05-04     9.449997
# 2021-06-10          NaN
# 2021-09-20    28.870026
# 2021-10-27          NaN
# 2021-12-03   -46.600006
# 2022-07-28          NaN
# dtype: float64

# %%
relprofits = (merged.shift(-1).Sells - merged.Buys)/merged.Buys

# %%
relprofits
# Out:
# Date
# 2021-02-25    0.058343
# 2021-04-01         NaN
# 2021-05-04    0.038137
# 2021-06-10         NaN
# 2021-09-20    0.098097
# 2021-10-27         NaN
# 2021-12-03   -0.144268
# 2022-07-28         NaN
# dtype: float64

# %%
relprofits.mean()
# Out:
# 0.01257738959757813
